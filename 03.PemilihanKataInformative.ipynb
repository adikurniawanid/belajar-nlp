# %%
from nltk.corpus import gutenberg
from nltk import word_tokenize, sent_tokenize, FreqDist

# %%
text=gutenberg.raw("blake-poems.txt")

# %%
wordToken = word_tokenize(text)
freqDist = FreqDist(wordToken)

# %%
freqDist.most_common(20)
# Out:
# [(',', 685),
#  ('the', 351),
#  ('.', 221),
#  ('And', 176),
#  ('and', 169),
#  ('of', 131),
#  ('I', 130),
#  ('in', 116),
#  ('a', 107),
#  (';', 99),
#  ('to', 92),
#  (':', 76),
#  ('my', 72),
#  ('!', 68),
#  ('?', 65),
#  ('The', 61),
#  ('with', 59),
#  ('``', 50),
#  ('his', 49),
#  ('is', 45)]

# %%
lenWord = [w for w in wordToken if len(w)>4]

# %%
lenWord
# Out:
# ['Poems',
#  'William',
#  'Blake',
#  'SONGS',
#  'INNOCENCE',
#  'EXPERIENCE',
#  'SONGS',
#  'INNOCENCE',
#  'INTRODUCTION',
#  'Piping',
#  'valleys',
#  'Piping',
#  'songs',
#  'pleasant',
#  'cloud',
#  'child',
#  'laughing',
#  'about',
#  'piped',
#  'merry',
#  'cheer',
#  'Piper',
#  'again',
#  'piped',
#  'happy',
#  'songs',
#  'happy',
#  'cheer',
#  'again',
#  'While',
#  'Piper',
#  'write',
#  'vanish',
#  'sight',
#  'pluck',
#  'hollow',
#  'rural',
#  'stain',
#  'water',
#  'clear',
#  'wrote',
#  'happy',
#  'songs',
#  'Every',
#  'child',
#  'SHEPHERD',
#  'sweet',
#  'Shepherd',
#  'sweet',
#  'evening',
#  'stays',
#  'shall',
#  'follow',
#  'sheep',
#  'tongue',
#  'shall',
#  'filled',
#  'praise',
#  'hears',
#  'lambs',
#  'innocent',
#  'hears',
#  'tender',
#  'reply',
#  'watching',
#  'while',
#  'peace',
#  'their',
#  'Shepherd',
#  'ECHOING',
#  'GREEN',
#  'arise',
#  'happy',
#  'skies',
#  'merry',
#  'bells',
#  'welcome',
#  'Spring',
#  'skylark',
#  'thrush',
#  'birds',
#  'louder',
#  'around',
#  'bells',
#  'cheerful',
#  'sound',
#  'While',
#  'sports',
#  'shall',
#  'echoing',
#  'Green',
#  'white',
#  'laugh',
#  'Sitting',
#  'under',
#  'Among',
#  'laugh',
#  'girls',
#  'youth-time',
#  'echoing',
#  'Green',
#  'little',
#  'weary',
#  'merry',
#  'descend',
#  'sports',
#  'Round',
#  'their',
#  'mothers',
#  'sisters',
#  'brothers',
#  'birds',
#  'their',
#  'ready',
#  'sport',
#  'darkening',
#  'green',
#  'Little',
#  'stream',
#  'clothing',
#  'delight',
#  'Softest',
#  'clothing',
#  'wolly',
#  'bright',
#  'tender',
#  'voice',
#  'Making',
#  'vales',
#  'rejoice',
#  'Little',
#  'Little',
#  'Little',
#  'called',
#  'calls',
#  'Himself',
#  'became',
#  'little',
#  'child',
#  'child',
#  'called',
#  'Little',
#  'bless',
#  'Little',
#  'bless',
#  'LITTLE',
#  'BLACK',
#  'mother',
#  'southern',
#  'black',
#  'white',
#  'White',
#  'angel',
#  'English',
#  'child',
#  'black',
#  'bereaved',
#  'light',
#  'mother',
#  'taught',
#  'underneath',
#  'sitting',
#  'before',
#  'kissed',
#  'pointed',
#  'began',
#  'rising',
#  'there',
#  'gives',
#  'light',
#  'gives',
#  'flowers',
#  'trees',
#  'beasts',
#  'receive',
#  'Comfort',
#  'morning',
#  'noonday',
#  'earth',
#  'little',
#  'space',
#  'learn',
#  'beams',
#  'these',
#  'black',
#  'bodies',
#  'sunburnt',
#  'cloud',
#  'shady',
#  'grove',
#  'souls',
#  'learn',
#  'cloud',
#  'vanish',
#  'shall',
#  'voice',
#  'Saying',
#  "'Come",
#  'grove',
#  'round',
#  'golden',
#  'lambs',
#  'rejoice',
#  'mother',
#  'kissed',
#  'little',
#  'English',
#  'black',
#  'white',
#  'cloud',
#  'round',
#  'lambs',
#  'shade',
#  'Father',
#  'stand',
#  'stroke',
#  'silver',
#  'BLOSSOM',
#  'Merry',
#  'merry',
#  'sparrow',
#  'Under',
#  'leaves',
#  'green',
#  'happy',
#  'blossom',
#  'swift',
#  'arrow',
#  'cradle',
#  'narrow',
#  'bosom',
#  'Pretty',
#  'pretty',
#  'robin',
#  'Under',
#  'leaves',
#  'green',
#  'happy',
#  'blossom',
#  'Hears',
#  'sobbing',
#  'sobbing',
#  'Pretty',
#  'pretty',
#  'robin',
#  'bosom',
#  'CHIMNEY-SWEEPER',
#  'mother',
#  'young',
#  'father',
#  'while',
#  'tongue',
#  'Could',
#  'scarcely',
#  'chimneys',
#  'sweep',
#  'sleep',
#  'There',
#  'little',
#  'Dacre',
#  'cried',
#  'curled',
#  'shaved',
#  'never',
#  'spoil',
#  'white',
#  'quiet',
#  'night',
#  'a-sleeping',
#  'sight',
#  'thousands',
#  'sweepers',
#  'locked',
#  'coffins',
#  'black',
#  'angel',
#  'bright',
#  'opened',
#  'coffins',
#  'green',
#  'plain',
#  'leaping',
#  'laughing',
#  'river',
#  'shine',
#  'naked',
#  'white',
#  'their',
#  'behind',
#  'clouds',
#  'sport',
#  'Angel',
#  'father',
#  'never',
#  'awoke',
#  'brushes',
#  'Though',
#  'morning',
#  'happy',
#  'their',
#  'LITTLE',
#  'Father',
#  'father',
#  'where',
#  'going',
#  'Speak',
#  'father',
#  'speak',
#  'little',
#  'shall',
#  'night',
#  'father',
#  'there',
#  'child',
#  'child',
#  'vapour',
#  'LITTLE',
#  'FOUND',
#  'little',
#  'lonely',
#  'wandering',
#  'light',
#  'Began',
#  'Appeared',
#  'father',
#  'white',
#  'kissed',
#  'child',
#  'mother',
#  'brought',
#  'sorrow',
#  'through',
#  'lonely',
#  'little',
#  'weeping',
#  'sought',
#  'LAUGHING',
#  'green',
#  'woods',
#  'laugh',
#  'voice',
#  'dimpling',
#  'stream',
#  'laughing',
#  'laugh',
#  'merry',
#  'green',
#  'laughs',
#  'noise',
#  'meadows',
#  'laugh',
#  'lively',
#  'green',
#  'grasshopper',
#  'laughs',
#  'merry',
#  'scene',
#  'Susan',
#  'Emily',
#  'their',
#  'sweet',
#  'round',
#  'mouths',
#  'painted',
#  'birds',
#  'laugh',
#  'shade',
#  'Where',
#  'table',
#  'cherries',
#  'spread',
#  'merry',
#  'sweet',
#  'chorus',
#  'Sweet',
#  'dreams',
#  'shade',
#  'lovely',
#  'infant',
#  'Sweet',
#  'dreams',
#  'pleasant',
#  'streams',
#  'happy',
#  'silent',
#  'moony',
#  'beams',
#  'Sweet',
#  'Sleep',
#  'Weave',
#  'brows',
#  'infant',
#  'crown',
#  'Sweet',
#  'Sleep',
#  'angel',
#  'Hover',
#  'happy',
#  'child',
#  'Sweet',
#  'smiles',
#  'night',
#  'Hover',
#  'delight',
#  'Sweet',
#  'smiles',
#  'mother',
#  'smile',
#  'livelong',
#  'night',
#  'beguile',
#  'Sweet',
#  'moans',
#  'dovelike',
#  'sighs',
#  'Chase',
#  'slumber',
#  'thine',
#  'Sweet',
#  'sweeter',
#  'smile',
#  'dovelike',
#  'moans',
#  'beguile',
#  'Sleep',
#  'sleep',
#  'happy',
#  'child',
#  'creation',
#  'slept',
#  'smiled',
#  'Sleep',
#  'sleep',
#  'happy',
#  'sleep',
#  'While',
#  'mother',
#  'Sweet',
#  'image',
#  'trace',
#  'Sweet',
#  'Maker',
#  'infant',
#  'small',
#  'image',
#  'Heavenly',
#  'smiles',
#  'Smiles',
#  'became',
#  'infant',
#  'small',
#  'Infant',
#  'smiles',
#  'smiles',
#  'Heaven',
#  'earth',
#  'peace',
#  'beguiles',
#  'DIVINE',
#  'IMAGE',
#  'Mercy',
#  'Peace',
#  'their',
#  'distress',
#  'these',
#  'virtues',
#  'delight',
#  'Return',
#  'their',
#  'thankfulness',
#  'Mercy',
#  'Peace',
#  'Father',
#  'Mercy',
#  'Peace',
#  'child',
#  'Mercy',
#  'human',
#  'heart',
#  'human',
#  'human',
#  'divine',
#  'Peace',
#  'human',
#  'dress',
#  'every',
#  'every',
#  'clime',
#  'prays',
#  'distress',
#  'Prays',
#  'human',
#  'divine',
#  'Mercy',
#  'Peace',
#  'human',
#  'heathen',
#  'Where',
#  'Mercy',
#  'dwell',
#  'There',
#  'dwelling',
#  'THURSDAY',
#  'Thursday',
#  'their',
#  'innocent',
#  'faces',
#  'clean',
#  'children',
#  'walking',
#  'green',
#  'Grey-headed',
#  'beadles',
#  'walked',
#  'before',
#  'wands',
#  'white',
#  'Thames',
#  'waters',
#  'multitude',
#  'seemed',
#  'these',
#  'flowers',
#  'London',
#  'Seated',
#  'companies',
#  'radiance',
#  'their',
#  'multitudes',
#  'there',
#  'multitudes',
#  'lambs',
#  'Thousands',
#  'little',
#  'girls',
#  'raising',
#  'their',
#  'innocent',
#  'hands',
#  'mighty',
#  'raise',
#  'heaven',
#  'voice',
#  'harmonious',
#  'thunderings',
#  'seats',
#  'heaven',
#  'among',
#  'Beneath',
#  'guardians',
#  'cherish',
#  'drive',
#  'angel',
#  'NIGHT',
#  'descending',
#  'evening',
#  'shine',
#  'birds',
#  'silent',
#  'their',
#  'flower',
#  'heaven',
#  'bower',
#  'silent',
#  'delight',
#  'smiles',
#  'night',
#  'Farewell',
#  'green',
#  'fields',
#  'happy',
#  'grove',
#  'Where',
#  'flocks',
#  "ta'en",
#  'delight',
#  'Where',
#  'lambs',
#  'nibbled',
#  'silent',
#  'angels',
#  'bright',
#  'Unseen',
#  'blessing',
#  'without',
#  'ceasing',
#  'blossom',
#  'sleeping',
#  'bosom',
#  'every',
#  'thoughtless',
#  'Where',
#  'birds',
#  'covered',
#  'visit',
#  'caves',
#  'every',
#  'beast',
#  'weeping',
#  'should',
#  'sleeping',
#  'sleep',
#  'their',
#  'their',
#  'wolves',
#  'tigers',
#  'pitying',
#  'stand',
#  'Seeking',
#  'drive',
#  'their',
#  'thirst',
#  'sheep',
#  'dreadful',
#  'angels',
#  'heedful',
#  'Receive',
#  'spirit',
#  'worlds',
#  'inherit',
#  'there',
#  'ruddy',
#  'Shall',
#  'tears',
#  'pitying',
#  'tender',
#  'cries',
#  'walking',
#  'round',
#  'Saying',
#  'Wrath',
#  'meekness',
#  'health',
#  'sickness',
#  'driven',
#  'immortal',
#  'beside',
#  'bleating',
#  'sleep',
#  'think',
#  'Graze',
#  'after',
#  'washed',
#  'river',
#  'bright',
#  'Shall',
#  'shine',
#  'guard',
#  'SPRING',
#  'Sound',
#  'flute',
#  'delight',
#  'night',
#  'Nightingale',
#  'Merrily',
#  'Merrily',
#  'merrily',
#  'welcome',
#  'Little',
#  'Little',
#  'Sweet',
#  'small',
#  'Merry',
#  'voice',
#  'Infant',
#  'noise',
#  'Merrily',
#  'merrily',
#  'welcome',
#  'Little',
#  'white',
#  'Merrily',
#  'merrily',
#  'welcome',
#  'NURSE',
#  'voices',
#  'children',
#  'heard',
#  'green',
#  'laughing',
#  'heard',
#  'heart',
#  'within',
#  'breast',
#  'everything',
#  'still',
#  'children',
#  'night',
#  'arise',
#  'leave',
#  'morning',
#  'appears',
#  'skies',
#  'sleep',
#  'Besides',
#  'little',
#  'birds',
#  'hills',
#  'covered',
#  'sheep',
#  'light',
#  'fades',
#  'little',
#  'leaped',
#  'shouted',
#  'laughed',
#  'hills',
#  'echoed',
#  'INFANT',
#  'shall',
#  'happy',
#  'Sweet',
#  'befall',
#  'Pretty',
#  'Sweet',
#  'Sweet',
#  'smile',
#  'while',
#  'Sweet',
#  'befall',
#  'DREAM',
#  'dream',
#  'weave',
#  'shade',
#  'angel-guarded',
#  'emmet',
#  'Where',
#  'grass',
#  'methought',
#  'Troubled',
#  'wildered',
#  'forlorn',
#  'benighted',
#  'travel-worn',
#  'tangle',
#  'spray',
#  'heart-broke',
#  'heard',
#  'children',
#  'their',
#  'father',
#  'abroad',
#  'return',
#  'Pitying',
#  'dropped',
#  'glow-worm',
#  'replied',
#  'wailing',
#  'wight',
#  'Calls',
#  'watchman',
#  'night',
#  'light',
#  'ground',
#  'While',
#  'beetle',
#  'round',
#  'Follow',
#  'beetle',
#  'Little',
#  'wanderer',
#  'ANOTHER',
#  'SORROW',
#  'another',
#  'sorrow',
#  'another',
#  'grief',
#  'relief',
#  'falling',
#  'sorrow',
#  'share',
#  'father',
#  'child',
#  'sorrow',
#  'filled',
#  'mother',
#  'infant',
#  'groan',
#  'infant',
#  'never',
#  'Never',
#  'never',
#  'smiles',
#  'sorrows',
#  'small',
#  'small',
#  'grief',
#  'infants',
#  'beside',
#  'Pouring',
#  'their',
#  'breast',
#  'cradle',
#  'Weeping',
#  'infant',
#  'night',
#  'Wiping',
#  'tears',
#  'never',
#  'Never',
#  'never',
#  'becomes',
#  'infant',
#  'small',
#  'becomes',
#  'sorrow',
#  'Think',
#  'canst',
#  'Maker',
#  'Think',
#  'canst',
#  'Maker',
#  'gives',
#  'grief',
#  'destroy',
#  'grief',
#  'SONGS',
#  'EXPERIENCE',
#  'INTRODUCTION',
#  'voice',
#  'present',
#  'future',
#  'Whose',
#  'heard',
#  'walked',
#  'among',
#  'ancient',
#  'Calling',
#  'lapsed',
#  'weeping',
#  'evening',
#  'might',
#  'control',
#  'starry',
#  'fallen',
#  'fallen',
#  'light',
#  'renew',
#  'Earth',
#  'Earth',
#  'return',
#  'Arise',
#  'grass',
#  'Night',
#  'Rises',
#  'slumbrous',
#  'starry',
#  'floor',
#  'watery',
#  'shore',
#  'given',
#  'break',
#  'EARTH',
#  'ANSWER',
#  'Earth',
#  'raised',
#  'darkness',
#  'dread',
#  'drear',
#  'light',
#  'Stony',
#  'dread',
#  'locks',
#  'covered',
#  'despair',
#  'Prisoned',
#  'watery',
#  'shore',
#  'Starry',
#  'jealousy',
#  'Weeping',
#  'father',
#  'ancient',
#  'Selfish',
#  'father',
#  'Cruel',
#  'jealous',
#  'selfish',
#  'delight',
#  'Chained',
#  'night',
#  'virgins',
#  'youth',
#  'morning',
#  'spring',
#  'blossoms',
#  'sower',
#  'night',
#  'plowman',
#  'darkness',
#  'plough',
#  'Break',
#  'heavy',
#  'chain',
#  'freeze',
#  'bones',
#  'around',
#  'Selfish',
#  'Eternal',
#  'bondage',
#  'bound',
#  'PEBBLE',
#  'seeketh',
#  'itself',
#  'please',
#  'itself',
#  'another',
#  'gives',
#  'builds',
#  'heaven',
#  'despair',
#  'little',
#  'Trodden',
#  'cattle',
#  'pebble',
#  'brook',
#  'Warbled',
#  'these',
#  'metres',
#  'seeketh',
#  'please',
#  'another',
#  'delight',
#  'another',
#  'builds',
#  'heaven',
#  'despite',
#  'THURSDAY',
#  'thing',
#  'fruitful',
#  'Babes',
#  'reduced',
#  'misery',
#  'usurous',
#  'trembling',
#  'children',
#  'poverty',
#  'their',
#  'never',
#  'shine',
#  'their',
#  'fields',
#  'bleak',
#  'their',
#  'filled',
#  'thorns',
#  'eternal',
#  'winter',
#  'there',
#  "where'er",
#  'shine',
#  "where'er",
#  'Babes',
#  'should',
#  'never',
#  'hunger',
#  'there',
#  'poverty',
#  'appall',
#  'LITTLE',
#  'futurity',
#  'prophetic',
#  'earth',
#  'sleep',
#  'Grave',
#  'sentence',
#  'Shall',
#  'arise',
#  'Maker',
#  'desert',
#  'Become',
#  'garden',
#  'southern',
#  'clime',
#  'Where',
#  'summer',
#  'prime',
#  'Never',
#  'fades',
#  'Lovely',
#  'Seven',
#  'summers',
#  'Lovely',
#  'wandered',
#  'Hearing',
#  'birds',
#  'Sweet',
#  'sleep',
#  'Underneath',
#  'father',
#  'mother',
#  'Where',
#  'sleep',
#  'desert',
#  'little',
#  'child',
#  'sleep',
#  'mother',
#  'heart',
#  'mother',
#  ...]

# %%
infWord = [w for w in wordToken if len(w)>6 and freqDist[w] > 6]

# %%
set(infWord)
# Out:
# {'another', 'children', 'delight', 'flowers', 'morning', 'through', 'weeping'}
